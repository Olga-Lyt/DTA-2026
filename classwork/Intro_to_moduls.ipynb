# %% [markdown]
# <a href="https://colab.research.google.com/github/Olga-Lyt/DTA-2026/blob/main/classwork/Intro_to_moduls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Знайомство з модулями у Python**

# %%
# !pip install numpy

# %%
import random  # random.randrange()
from random import randrange  # randrange()

from random import * # randrange()
import random as rnd # rnd.randrange()
from random import randrange as rndrng  # randrange()

# %%
import random
random.randrange(1, 11, 2)
# Out:
# 9

# %%
random.choice(['q', 'w', 'e', 'r', 't', 'y'])
# Out:
# 't'

# %%
def function():
    d = list(range(1, 11, 2))
    d[-1] += 1
    print(d)

function()
# Out:
# [1, 3, 5, 7, 10]
